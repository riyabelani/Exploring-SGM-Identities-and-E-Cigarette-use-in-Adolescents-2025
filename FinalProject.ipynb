# %% [markdown]
# # Literature Review

# %% [markdown]
# >Riya Belani

# %% [markdown]
# ## Subtitle

# %% [markdown]
# normal sentence

# %% [markdown]
# This is an equation $y=mx+b$

# %% [markdown]
# $$
# \begin{align*}
# E &=mc^{2.3} \\ \\
# f(x)&=3x + 5
# \end{align*}
# \tag{1}$$

# %% [markdown]
# ![](GWU_Logo_Horizontal.png)

# %%
Cell In[1], line 2
#
